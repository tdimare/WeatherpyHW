# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
from pprint import pprint

# Import API key
#from api_keys import api_key
api_key = "api_key"

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
#%pwd

# %%
#import os
#files = [f for f in os.listdir('.') if os.path.isfile(f)]
#print(files)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 630

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#url for get requests to retrieve weather data 
    #url = "https://api.openweathermap.org/data/2.5/weather?q=San Francisco&APPID="+api_key
    #response = requests.get(url).json()
    #print(json.dumps(response, indent=4, sort_keys=True))

# %%
#url for get requests to retrieve weather data 
#url = "https://api.openweathermap.org/data/2.5/weather?q=Seattle&APPID="+api_key
#response = requests.get(url).json()
#print(json.dumps(response, indent=4, sort_keys=True))

# %%
#url for get requests to retrieve weather data 
#url = "https://api.openweathermap.org/data/2.5/weather?q=San Diego&APPID="+api_key
#response = requests.get(url).json()
#print(json.dumps(response, indent=4, sort_keys=True))

# %%
#url for get requests to retrieve weather data 
#url = "https://api.openweathermap.org/data/2.5/weather?q=Portland&APPID="+api_key
#response = requests.get(url).json()
#print(json.dumps(response, indent=4, sort_keys=True))

# %%
#url for get requests to retrieve weather data 
#url = "https://api.openweathermap.org/data/2.5/weather?q=Los Angeles&APPID="+api_key
#response = requests.get(url).json()
#print(json.dumps(response, indent=4, sort_keys=True))

# %%
#url for get requests to retrieve weather data 
#url = "https://api.openweathermap.org/data/2.5/weather?q=Denver&APPID="+api_key
#response = requests.get(url).json()
#print(json.dumps(response, indent=4, sort_keys=True))

# %%
#print(response)

# %%
#pprint(response)

# %%
#response["name"]

# %%
#response["main"]["humidity"]

# %%
#response["weather"][0]["description"]

# %%
#response["wind"]["deg"]

# %%
#response["wind"]["speed"]

# %%
#response["main"]["temp"]

# %%
for city in cities[0:5]:
    url = "https://api.openweathermap.org/data/2.5/weather?q="+city+"&APPID="+api_key
    print(url)
    response = requests.get(url).json()
    try:
        city_humidity = response["main"]["humidity"]
        print(city_humidity)
    except: 
        pass
# Out:
# https://api.openweathermap.org/data/2.5/weather?q=busselton&APPID=api_key
# 66
# https://api.openweathermap.org/data/2.5/weather?q=albany&APPID=api_key
# 73
# https://api.openweathermap.org/data/2.5/weather?q=ushuaia&APPID=api_key
# 94
# https://api.openweathermap.org/data/2.5/weather?q=vaini&APPID=api_key
# 90
# https://api.openweathermap.org/data/2.5/weather?q=taolanaro&APPID=api_key

# %%
for city in cities[0:5]:
    url = "https://api.openweathermap.org/data/2.5/weather?q="+city+"&APPID="+api_key
    print(url)
    response = requests.get(url).json()
    try:
        city_windspeed = response["wind"]["speed"]
        print(city_windspeed)
    except: 
        pass
# Out:
# https://api.openweathermap.org/data/2.5/weather?q=busselton&APPID=api_key
# 9.01
# https://api.openweathermap.org/data/2.5/weather?q=albany&APPID=api_key
# 4.1
# https://api.openweathermap.org/data/2.5/weather?q=ushuaia&APPID=api_key
# 2.1
# https://api.openweathermap.org/data/2.5/weather?q=vaini&APPID=api_key
# 0.56
# https://api.openweathermap.org/data/2.5/weather?q=taolanaro&APPID=api_key

# %%
for city in cities[0:5]:
    url = "https://api.openweathermap.org/data/2.5/weather?q="+city+"&APPID="+api_key
    print(url)
    response = requests.get(url).json()
    try:
        city_weather = response["weather"][0]["description"]
        print(city_weather)
    except: 
        pass
# Out:
# https://api.openweathermap.org/data/2.5/weather?q=busselton&APPID=api_key
# scattered clouds
# https://api.openweathermap.org/data/2.5/weather?q=albany&APPID=api_key
# clear sky
# https://api.openweathermap.org/data/2.5/weather?q=ushuaia&APPID=api_key
# few clouds
# https://api.openweathermap.org/data/2.5/weather?q=vaini&APPID=api_key
# light rain
# https://api.openweathermap.org/data/2.5/weather?q=taolanaro&APPID=api_key

# %%
for city in cities[0:5]:
    url = "https://api.openweathermap.org/data/2.5/weather?q="+city+"&APPID="+api_key
    print(url)
    response = requests.get(url).json()
    try:
        city_temperature = response["main"]["temp"]
        city_temperature_converted = ((city_temperature-32)*5/9)
        print(city_temperature)
    except: 
        pass
# Out:
# https://api.openweathermap.org/data/2.5/weather?q=busselton&APPID=api_key
# 280.69
# https://api.openweathermap.org/data/2.5/weather?q=albany&APPID=api_key
# 296.44
# https://api.openweathermap.org/data/2.5/weather?q=ushuaia&APPID=api_key
# 276.15
# https://api.openweathermap.org/data/2.5/weather?q=vaini&APPID=api_key
# 297.81
# https://api.openweathermap.org/data/2.5/weather?q=taolanaro&APPID=api_key

# %%
city_name = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
city_temperature = []
wind_speed = []

# Start counter 
record = 1

print(f"API Starting")
print(f"===================================")

# Loop through all cities in the list
for city in cities:  
    
    try:
        url = "https://api.openweathermap.org/data/2.5/weather?q="+city+"&APPID="+api_key
        response = requests.get(url).json()
        city_name.append(response["name"])
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        city_temperature.append(response["main"]["temp"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        wind_speed.append(response["wind"]["speed"])
        city_record = response["name"]
        print(f"City Record {record} | {city_record}")
        print(url)
        
        # Add to counter
        record= record + 1
        
        # API rate limit
        time.sleep(1.01)
        
    # Skip if no match found
    except Exception as e:
        print("Exception for city", city)
        print(e)
    continue
# Out:
# API Starting
# ===================================
# City Record 1 | Busselton
# https://api.openweathermap.org/data/2.5/weather?q=busselton&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 2 | Albany
# https://api.openweathermap.org/data/2.5/weather?q=albany&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 3 | Ushuaia
# https://api.openweathermap.org/data/2.5/weather?q=ushuaia&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 4 | Vaini
# https://api.openweathermap.org/data/2.5/weather?q=vaini&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# Exception for city taolanaro
# 'name'
# City Record 5 | Geraldton
# https://api.openweathermap.org/data/2.5/weather?q=geraldton&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 6 | Sadiqabad
# https://api.openweathermap.org/data/2.5/weather?q=sadiqabad&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 7 | Tuatapere
# https://api.openweathermap.org/data/2.5/weather?q=tuatapere&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 8 | Faanui
# https://api.openweathermap.org/data/2.5/weather?q=faanui&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 9 | Rikitea
# https://api.openweathermap.org/data/2.5/weather?q=rikitea&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 10 | Provideniya
# https://api.openweathermap.org/data/2.5/weather?q=provideniya&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 11 | Dunedin
# https://api.openweathermap.org/data/2.5/weather?q=dunedin&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 12 | Bassar
# https://api.openweathermap.org/data/2.5/weather?q=bassar&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 13 | Along
# https://api.openweathermap.org/data/2.5/weather?q=along&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 14 | Inhambane
# https://api.openweathermap.org/data/2.5/weather?q=inhambane&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 15 | Penapolis
# https://api.openweathermap.org/data/2.5/weather?q=penapolis&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 16 | East London
# https://api.openweathermap.org/data/2.5/weather?q=east london&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 17 | Bluff
# https://api.openweathermap.org/data/2.5/weather?q=bluff&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# Exception for city vaitupu
# 'name'
# City Record 18 | Mehamn
# https://api.openweathermap.org/data/2.5/weather?q=mehamn&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# Exception for city grand river south east
# 'name'
# Exception for city ijaki
# 'name'
# City Record 19 | Saskylakh
# https://api.openweathermap.org/data/2.5/weather?q=saskylakh&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 20 | Naryan-Mar
# https://api.openweathermap.org/data/2.5/weather?q=naryan-mar&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 21 | Punta Arenas
# https://api.openweathermap.org/data/2.5/weather?q=punta arenas&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 22 | Palu
# https://api.openweathermap.org/data/2.5/weather?q=palu&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 23 | Dikson
# https://api.openweathermap.org/data/2.5/weather?q=dikson&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 24 | Sitka
# https://api.openweathermap.org/data/2.5/weather?q=sitka&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 25 | Walvis Bay
# https://api.openweathermap.org/data/2.5/weather?q=walvis bay&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 26 | Bathsheba
# https://api.openweathermap.org/data/2.5/weather?q=bathsheba&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 27 | Saint-Philippe
# https://api.openweathermap.org/data/2.5/weather?q=saint-philippe&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 28 | Belaya Gora
# https://api.openweathermap.org/data/2.5/weather?q=belaya gora&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# Exception for city araguacu
# 'name'
# City Record 29 | Sierpc
# https://api.openweathermap.org/data/2.5/weather?q=sierpc&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 30 | Otradnoye
# https://api.openweathermap.org/data/2.5/weather?q=otradnoye&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 31 | Manzanillo
# https://api.openweathermap.org/data/2.5/weather?q=manzanillo&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 32 | Puerto Ayora
# https://api.openweathermap.org/data/2.5/weather?q=puerto ayora&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 33 | Avarua
# https://api.openweathermap.org/data/2.5/weather?q=avarua&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 34 | Bafq
# https://api.openweathermap.org/data/2.5/weather?q=bafq&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 35 | Barrow
# https://api.openweathermap.org/data/2.5/weather?q=barrow&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 36 | Kavieng
# https://api.openweathermap.org/data/2.5/weather?q=kavieng&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 37 | Chumikan
# https://api.openweathermap.org/data/2.5/weather?q=chumikan&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 38 | Carnarvon
# https://api.openweathermap.org/data/2.5/weather?q=carnarvon&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 39 | Mahebourg
# https://api.openweathermap.org/data/2.5/weather?q=mahebourg&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 40 | Port Alfred
# https://api.openweathermap.org/data/2.5/weather?q=port alfred&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 41 | Georgetown
# https://api.openweathermap.org/data/2.5/weather?q=georgetown&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 42 | Itarema
# https://api.openweathermap.org/data/2.5/weather?q=itarema&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# Exception for city barentsburg
# 'name'
# City Record 43 | Ahipara
# https://api.openweathermap.org/data/2.5/weather?q=ahipara&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 44 | Mataura
# https://api.openweathermap.org/data/2.5/weather?q=mataura&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 45 | Henties Bay
# https://api.openweathermap.org/data/2.5/weather?q=henties bay&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# Exception for city tsihombe
# 'name'
# City Record 46 | Russell
# https://api.openweathermap.org/data/2.5/weather?q=russell&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# Exception for city burica
# 'name'
# City Record 47 | Havre-Saint-Pierre
# https://api.openweathermap.org/data/2.5/weather?q=havre-saint-pierre&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 48 | Luoyang
# https://api.openweathermap.org/data/2.5/weather?q=luoyang&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 49 | Gigmoto
# https://api.openweathermap.org/data/2.5/weather?q=gigmoto&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 50 | Cherskiy
# https://api.openweathermap.org/data/2.5/weather?q=cherskiy&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 51 | College
# https://api.openweathermap.org/data/2.5/weather?q=college&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 52 | Severo-Kurilsk
# https://api.openweathermap.org/data/2.5/weather?q=severo-kurilsk&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 53 | Castro
# https://api.openweathermap.org/data/2.5/weather?q=castro&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 54 | Hermanus
# https://api.openweathermap.org/data/2.5/weather?q=hermanus&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 55 | Oktyabrskiy
# https://api.openweathermap.org/data/2.5/weather?q=oktyabrskiy&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 56 | Belyy Yar
# https://api.openweathermap.org/data/2.5/weather?q=belyy yar&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 57 | Felipe Carrillo Puerto
# https://api.openweathermap.org/data/2.5/weather?q=felipe carrillo puerto&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 58 | Xuddur
# https://api.openweathermap.org/data/2.5/weather?q=xuddur&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 59 | Pevek
# https://api.openweathermap.org/data/2.5/weather?q=pevek&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 60 | Leshukonskoye
# https://api.openweathermap.org/data/2.5/weather?q=leshukonskoye&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# Exception for city sakakah
# 'name'
# City Record 61 | Jamestown
# https://api.openweathermap.org/data/2.5/weather?q=jamestown&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 62 | Ust-Tsilma
# https://api.openweathermap.org/data/2.5/weather?q=ust-tsilma&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 63 | Saint-Joseph
# https://api.openweathermap.org/data/2.5/weather?q=saint-joseph&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 64 | Husavik
# https://api.openweathermap.org/data/2.5/weather?q=husavik&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 65 | Suclayin
# https://api.openweathermap.org/data/2.5/weather?q=suclayin&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 66 | New Norfolk
# https://api.openweathermap.org/data/2.5/weather?q=new norfolk&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 67 | Hobart
# https://api.openweathermap.org/data/2.5/weather?q=hobart&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# Exception for city maarianhamina
# 'name'
# City Record 68 | Los Llanos de Aridane
# https://api.openweathermap.org/data/2.5/weather?q=los llanos de aridane&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 69 | Salalah
# https://api.openweathermap.org/data/2.5/weather?q=salalah&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# Exception for city amderma
# 'name'
# City Record 70 | Marawi
# https://api.openweathermap.org/data/2.5/weather?q=marawi&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 71 | Raudeberg
# https://api.openweathermap.org/data/2.5/weather?q=raudeberg&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 72 | Yellowknife
# https://api.openweathermap.org/data/2.5/weather?q=yellowknife&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 73 | Lebu
# https://api.openweathermap.org/data/2.5/weather?q=lebu&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 74 | Chokurdakh
# https://api.openweathermap.org/data/2.5/weather?q=chokurdakh&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 75 | Taunggyi
# https://api.openweathermap.org/data/2.5/weather?q=taunggyi&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 76 | Airai
# https://api.openweathermap.org/data/2.5/weather?q=airai&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 77 | Butaritari
# https://api.openweathermap.org/data/2.5/weather?q=butaritari&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 78 | Uspenka
# https://api.openweathermap.org/data/2.5/weather?q=uspenka&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# Exception for city kleck
# 'name'
# Exception for city usevya
# 'name'
# City Record 79 | Cidreira
# https://api.openweathermap.org/data/2.5/weather?q=cidreira&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 80 | Sechura
# https://api.openweathermap.org/data/2.5/weather?q=sechura&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 81 | Dutlwe
# https://api.openweathermap.org/data/2.5/weather?q=dutlwe&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 82 | Sabinas
# https://api.openweathermap.org/data/2.5/weather?q=sabinas&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 83 | Saint George
# https://api.openweathermap.org/data/2.5/weather?q=saint george&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 84 | Lermontovka
# https://api.openweathermap.org/data/2.5/weather?q=lermontovka&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 85 | Santa Cruz
# https://api.openweathermap.org/data/2.5/weather?q=santa cruz&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# Exception for city yakshur-bodya
# 'name'
# City Record 86 | Sibolga
# https://api.openweathermap.org/data/2.5/weather?q=sibolga&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 87 | Atuona
# https://api.openweathermap.org/data/2.5/weather?q=atuona&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 88 | Falmouth
# https://api.openweathermap.org/data/2.5/weather?q=falmouth&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 89 | Bredasdorp
# https://api.openweathermap.org/data/2.5/weather?q=bredasdorp&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 90 | Turukhansk
# https://api.openweathermap.org/data/2.5/weather?q=turukhansk&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# Exception for city bengkulu
# 'name'
# City Record 91 | Port Elizabeth
# https://api.openweathermap.org/data/2.5/weather?q=port elizabeth&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 92 | Beringovskiy
# https://api.openweathermap.org/data/2.5/weather?q=beringovskiy&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 93 | Saldanha
# https://api.openweathermap.org/data/2.5/weather?q=saldanha&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 94 | Springbok
# https://api.openweathermap.org/data/2.5/weather?q=springbok&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 95 | Victoria
# https://api.openweathermap.org/data/2.5/weather?q=victoria&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 96 | Longyearbyen
# https://api.openweathermap.org/data/2.5/weather?q=longyearbyen&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 97 | Cockburn Town
# https://api.openweathermap.org/data/2.5/weather?q=cockburn town&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 98 | Kudahuvadhoo
# https://api.openweathermap.org/data/2.5/weather?q=kudahuvadhoo&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 99 | Puerto Escondido
# https://api.openweathermap.org/data/2.5/weather?q=puerto escondido&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 100 | Cape Town
# https://api.openweathermap.org/data/2.5/weather?q=cape town&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 101 | Esperance
# https://api.openweathermap.org/data/2.5/weather?q=esperance&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 102 | Sola
# https://api.openweathermap.org/data/2.5/weather?q=sola&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 103 | Pangkalanbuun
# https://api.openweathermap.org/data/2.5/weather?q=pangkalanbuun&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 104 | Muravlenko
# https://api.openweathermap.org/data/2.5/weather?q=muravlenko&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 105 | Buncrana
# https://api.openweathermap.org/data/2.5/weather?q=buncrana&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 106 | Chuy
# https://api.openweathermap.org/data/2.5/weather?q=chuy&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 107 | Sibu
# https://api.openweathermap.org/data/2.5/weather?q=sibu&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# Exception for city samusu
# 'name'
# Exception for city sentyabrskiy
# 'name'
# City Record 108 | Iqaluit
# https://api.openweathermap.org/data/2.5/weather?q=iqaluit&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 109 | Shanting
# https://api.openweathermap.org/data/2.5/weather?q=shanting&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 110 | Sayyan
# https://api.openweathermap.org/data/2.5/weather?q=sayyan&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 111 | Avera
# https://api.openweathermap.org/data/2.5/weather?q=avera&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 112 | Ambulu
# https://api.openweathermap.org/data/2.5/weather?q=ambulu&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 113 | Torbay
# https://api.openweathermap.org/data/2.5/weather?q=torbay&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 114 | Bilma
# https://api.openweathermap.org/data/2.5/weather?q=bilma&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 115 | Kokkola
# https://api.openweathermap.org/data/2.5/weather?q=kokkola&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 116 | Isangel
# https://api.openweathermap.org/data/2.5/weather?q=isangel&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 117 | Sabha
# https://api.openweathermap.org/data/2.5/weather?q=sabha&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 118 | Luena
# https://api.openweathermap.org/data/2.5/weather?q=luena&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 119 | Kahului
# https://api.openweathermap.org/data/2.5/weather?q=kahului&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 120 | Hilo
# https://api.openweathermap.org/data/2.5/weather?q=hilo&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 121 | Mar del Plata
# https://api.openweathermap.org/data/2.5/weather?q=mar del plata&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 122 | Nishihara
# https://api.openweathermap.org/data/2.5/weather?q=nishihara&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 123 | Yumen
# https://api.openweathermap.org/data/2.5/weather?q=yumen&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 124 | Kirakira
# https://api.openweathermap.org/data/2.5/weather?q=kirakira&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 125 | Camara de Lobos
# https://api.openweathermap.org/data/2.5/weather?q=camara de lobos&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 126 | Bulungu
# https://api.openweathermap.org/data/2.5/weather?q=bulungu&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 127 | Matagami
# https://api.openweathermap.org/data/2.5/weather?q=matagami&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 128 | Vanderhoof
# https://api.openweathermap.org/data/2.5/weather?q=vanderhoof&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 129 | Pangai
# https://api.openweathermap.org/data/2.5/weather?q=pangai&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 130 | Muncar
# https://api.openweathermap.org/data/2.5/weather?q=muncar&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 131 | Te Anau
# https://api.openweathermap.org/data/2.5/weather?q=te anau&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 132 | Conde
# https://api.openweathermap.org/data/2.5/weather?q=conde&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 133 | General Jose Eduvigis Diaz
# https://api.openweathermap.org/data/2.5/weather?q=general jose eduvigis diaz&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# Exception for city palabuhanratu
# 'name'
# City Record 134 | Key Largo
# https://api.openweathermap.org/data/2.5/weather?q=key largo&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 135 | Tiksi
# https://api.openweathermap.org/data/2.5/weather?q=tiksi&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 136 | Pa Daet
# https://api.openweathermap.org/data/2.5/weather?q=pa daet&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 137 | Reconquista
# https://api.openweathermap.org/data/2.5/weather?q=reconquista&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 138 | Bam
# https://api.openweathermap.org/data/2.5/weather?q=bam&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 139 | Thinadhoo
# https://api.openweathermap.org/data/2.5/weather?q=thinadhoo&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 140 | Diamantino
# https://api.openweathermap.org/data/2.5/weather?q=diamantino&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# Exception for city sorvag
# 'name'
# City Record 141 | Winneba
# https://api.openweathermap.org/data/2.5/weather?q=winneba&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 142 | Carnot
# https://api.openweathermap.org/data/2.5/weather?q=carnot&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 143 | Kiruna
# https://api.openweathermap.org/data/2.5/weather?q=kiruna&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 144 | Kapaa
# https://api.openweathermap.org/data/2.5/weather?q=kapaa&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 145 | Yoichi
# https://api.openweathermap.org/data/2.5/weather?q=yoichi&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 146 | Kodiak
# https://api.openweathermap.org/data/2.5/weather?q=kodiak&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 147 | Arraial do Cabo
# https://api.openweathermap.org/data/2.5/weather?q=arraial do cabo&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 148 | Kloulklubed
# https://api.openweathermap.org/data/2.5/weather?q=kloulklubed&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 149 | Nikolskoye
# https://api.openweathermap.org/data/2.5/weather?q=nikolskoye&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 150 | Weligama
# https://api.openweathermap.org/data/2.5/weather?q=weligama&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 151 | Port Hardy
# https://api.openweathermap.org/data/2.5/weather?q=port hardy&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 152 | Zhigansk
# https://api.openweathermap.org/data/2.5/weather?q=zhigansk&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# Exception for city mullaitivu
# 'name'
# City Record 153 | Muli
# https://api.openweathermap.org/data/2.5/weather?q=muli&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 154 | Ilulissat
# https://api.openweathermap.org/data/2.5/weather?q=ilulissat&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 155 | Jumla
# https://api.openweathermap.org/data/2.5/weather?q=jumla&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 156 | Touros
# https://api.openweathermap.org/data/2.5/weather?q=touros&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 157 | Anupgarh
# https://api.openweathermap.org/data/2.5/weather?q=anupgarh&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# Exception for city attawapiskat
# 'name'
# City Record 158 | Whitecourt
# https://api.openweathermap.org/data/2.5/weather?q=whitecourt&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 159 | Machilipatnam
# https://api.openweathermap.org/data/2.5/weather?q=machilipatnam&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 160 | Khatanga
# https://api.openweathermap.org/data/2.5/weather?q=khatanga&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 161 | Mandera
# https://api.openweathermap.org/data/2.5/weather?q=mandera&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 162 | Luderitz
# https://api.openweathermap.org/data/2.5/weather?q=luderitz&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 163 | Plastun
# https://api.openweathermap.org/data/2.5/weather?q=plastun&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 164 | Ust-Maya
# https://api.openweathermap.org/data/2.5/weather?q=ust-maya&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 165 | Coihaique
# https://api.openweathermap.org/data/2.5/weather?q=coihaique&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 166 | Ostrovnoy
# https://api.openweathermap.org/data/2.5/weather?q=ostrovnoy&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 167 | Bambous Virieux
# https://api.openweathermap.org/data/2.5/weather?q=bambous virieux&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 168 | Muttupet
# https://api.openweathermap.org/data/2.5/weather?q=muttupet&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 169 | Cartagena
# https://api.openweathermap.org/data/2.5/weather?q=cartagena&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 170 | Mitsamiouli
# https://api.openweathermap.org/data/2.5/weather?q=mitsamiouli&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# Exception for city nizhneyansk
# 'name'
# City Record 171 | Luba
# https://api.openweathermap.org/data/2.5/weather?q=luba&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 172 | Sabang
# https://api.openweathermap.org/data/2.5/weather?q=sabang&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 173 | Correntina
# https://api.openweathermap.org/data/2.5/weather?q=correntina&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 174 | Marsa Matruh
# https://api.openweathermap.org/data/2.5/weather?q=marsa matruh&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 175 | Ancud
# https://api.openweathermap.org/data/2.5/weather?q=ancud&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 176 | Brentwood
# https://api.openweathermap.org/data/2.5/weather?q=brentwood&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 177 | Lima
# https://api.openweathermap.org/data/2.5/weather?q=lima&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# Exception for city andenes
# 'name'
# City Record 178 | Olds
# https://api.openweathermap.org/data/2.5/weather?q=olds&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 179 | Kantang
# https://api.openweathermap.org/data/2.5/weather?q=kantang&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 180 | Norman Wells
# https://api.openweathermap.org/data/2.5/weather?q=norman wells&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 181 | Natal
# https://api.openweathermap.org/data/2.5/weather?q=natal&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 182 | Sudzha
# https://api.openweathermap.org/data/2.5/weather?q=sudzha&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 183 | Yenagoa
# https://api.openweathermap.org/data/2.5/weather?q=yenagoa&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 184 | Namatanai
# https://api.openweathermap.org/data/2.5/weather?q=namatanai&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 185 | Sorland
# https://api.openweathermap.org/data/2.5/weather?q=sorland&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 186 | Slave Lake
# https://api.openweathermap.org/data/2.5/weather?q=slave lake&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 187 | Lenoir City
# https://api.openweathermap.org/data/2.5/weather?q=lenoir city&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 188 | Jalu
# https://api.openweathermap.org/data/2.5/weather?q=jalu&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# Exception for city bolungarvik
# 'name'
# City Record 189 | Fort Nelson
# https://api.openweathermap.org/data/2.5/weather?q=fort nelson&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 190 | Vostok
# https://api.openweathermap.org/data/2.5/weather?q=vostok&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 191 | Sangar
# https://api.openweathermap.org/data/2.5/weather?q=sangar&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 192 | Portree
# https://api.openweathermap.org/data/2.5/weather?q=portree&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 193 | Madaoua
# https://api.openweathermap.org/data/2.5/weather?q=madaoua&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 194 | Cervo
# https://api.openweathermap.org/data/2.5/weather?q=cervo&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 195 | Rocha
# https://api.openweathermap.org/data/2.5/weather?q=rocha&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 196 | Souillac
# https://api.openweathermap.org/data/2.5/weather?q=souillac&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# Exception for city mancio lima
# 'name'
# City Record 197 | Chapais
# https://api.openweathermap.org/data/2.5/weather?q=chapais&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# Exception for city olafsvik
# 'name'
# City Record 198 | Gazimurskiy Zavod
# https://api.openweathermap.org/data/2.5/weather?q=gazimurskiy zavod&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 199 | Davila
# https://api.openweathermap.org/data/2.5/weather?q=davila&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 200 | Biak
# https://api.openweathermap.org/data/2.5/weather?q=biak&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 201 | Andilamena
# https://api.openweathermap.org/data/2.5/weather?q=andilamena&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 202 | San Patricio
# https://api.openweathermap.org/data/2.5/weather?q=san patricio&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 203 | Port Shepstone
# https://api.openweathermap.org/data/2.5/weather?q=port shepstone&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 204 | Tasiilaq
# https://api.openweathermap.org/data/2.5/weather?q=tasiilaq&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 205 | Rundu
# https://api.openweathermap.org/data/2.5/weather?q=rundu&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 206 | Vila Franca do Campo
# https://api.openweathermap.org/data/2.5/weather?q=vila franca do campo&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 207 | Bremervorde
# https://api.openweathermap.org/data/2.5/weather?q=bremervorde&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 208 | Union
# https://api.openweathermap.org/data/2.5/weather?q=union&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# Exception for city tawkar
# 'name'
# City Record 209 | Ribeira Grande
# https://api.openweathermap.org/data/2.5/weather?q=ribeira grande&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# Exception for city illoqqortoormiut
# 'name'
# City Record 210 | Tommot
# https://api.openweathermap.org/data/2.5/weather?q=tommot&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 211 | Grindavik
# https://api.openweathermap.org/data/2.5/weather?q=grindavik&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 212 | Solnechnyy
# https://api.openweathermap.org/data/2.5/weather?q=solnechnyy&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 213 | Tuktoyaktuk
# https://api.openweathermap.org/data/2.5/weather?q=tuktoyaktuk&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 214 | Baruun-Urt
# https://api.openweathermap.org/data/2.5/weather?q=baruun-urt&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 215 | Sobreira
# https://api.openweathermap.org/data/2.5/weather?q=sobreira&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 216 | Salinas
# https://api.openweathermap.org/data/2.5/weather?q=salinas&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 217 | Trinidad
# https://api.openweathermap.org/data/2.5/weather?q=trinidad&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 218 | Emporia
# https://api.openweathermap.org/data/2.5/weather?q=emporia&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 219 | Abu Dhabi
# https://api.openweathermap.org/data/2.5/weather?q=abu dhabi&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 220 | Sokoto
# https://api.openweathermap.org/data/2.5/weather?q=sokoto&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 221 | Ferkessedougou
# https://api.openweathermap.org/data/2.5/weather?q=ferkessedougou&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 222 | Ponta Delgada
# https://api.openweathermap.org/data/2.5/weather?q=ponta delgada&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 223 | Ostersund
# https://api.openweathermap.org/data/2.5/weather?q=ostersund&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 224 | Thai Nguyen
# https://api.openweathermap.org/data/2.5/weather?q=thai nguyen&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 225 | Pacific Grove
# https://api.openweathermap.org/data/2.5/weather?q=pacific grove&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 226 | Cabo San Lucas
# https://api.openweathermap.org/data/2.5/weather?q=cabo san lucas&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 227 | Pierre
# https://api.openweathermap.org/data/2.5/weather?q=pierre&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# Exception for city mys shmidta
# 'name'
# City Record 228 | San Vicente
# https://api.openweathermap.org/data/2.5/weather?q=san vicente&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 229 | Feijo
# https://api.openweathermap.org/data/2.5/weather?q=feijo&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 230 | Helong
# https://api.openweathermap.org/data/2.5/weather?q=helong&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 231 | Namibe
# https://api.openweathermap.org/data/2.5/weather?q=namibe&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 232 | Sawakin
# https://api.openweathermap.org/data/2.5/weather?q=sawakin&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 233 | Winburg
# https://api.openweathermap.org/data/2.5/weather?q=winburg&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 234 | Troitskoye
# https://api.openweathermap.org/data/2.5/weather?q=troitskoye&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# Exception for city tabialan
# 'name'
# City Record 235 | Acapulco
# https://api.openweathermap.org/data/2.5/weather?q=acapulco&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 236 | Ponta do Sol
# https://api.openweathermap.org/data/2.5/weather?q=ponta do sol&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 237 | Lagoa
# https://api.openweathermap.org/data/2.5/weather?q=lagoa&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 238 | Komsomolskiy
# https://api.openweathermap.org/data/2.5/weather?q=komsomolskiy&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 239 | Muroto
# https://api.openweathermap.org/data/2.5/weather?q=muroto&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 240 | Praia da Vitoria
# https://api.openweathermap.org/data/2.5/weather?q=praia da vitoria&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 241 | Lavrentiya
# https://api.openweathermap.org/data/2.5/weather?q=lavrentiya&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# Exception for city korla
# 'name'
# City Record 242 | Catalina
# https://api.openweathermap.org/data/2.5/weather?q=catalina&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 243 | San Cristobal
# https://api.openweathermap.org/data/2.5/weather?q=san cristobal&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 244 | Mvuma
# https://api.openweathermap.org/data/2.5/weather?q=mvuma&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 245 | Pfullingen
# https://api.openweathermap.org/data/2.5/weather?q=pfullingen&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 246 | Mangrol
# https://api.openweathermap.org/data/2.5/weather?q=mangrol&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 247 | Soyo
# https://api.openweathermap.org/data/2.5/weather?q=soyo&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 248 | Buala
# https://api.openweathermap.org/data/2.5/weather?q=buala&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 249 | Port Hedland
# https://api.openweathermap.org/data/2.5/weather?q=port hedland&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 250 | Bethel
# https://api.openweathermap.org/data/2.5/weather?q=bethel&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 251 | Lompoc
# https://api.openweathermap.org/data/2.5/weather?q=lompoc&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 252 | Qaqortoq
# https://api.openweathermap.org/data/2.5/weather?q=qaqortoq&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 253 | Hamburg
# https://api.openweathermap.org/data/2.5/weather?q=hamburg&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 254 | Bonavista
# https://api.openweathermap.org/data/2.5/weather?q=bonavista&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 255 | Hithadhoo
# https://api.openweathermap.org/data/2.5/weather?q=hithadhoo&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 256 | Libertador General San Martin
# https://api.openweathermap.org/data/2.5/weather?q=libertador general san martin&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 257 | Vygonichi
# https://api.openweathermap.org/data/2.5/weather?q=vygonichi&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 258 | Mufumbwe
# https://api.openweathermap.org/data/2.5/weather?q=mufumbwe&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 259 | Boffa
# https://api.openweathermap.org/data/2.5/weather?q=boffa&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 260 | Ullapool
# https://api.openweathermap.org/data/2.5/weather?q=ullapool&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# Exception for city belushya guba
# 'name'
# City Record 261 | Sinaloa
# https://api.openweathermap.org/data/2.5/weather?q=sinaloa&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 262 | Codrington
# https://api.openweathermap.org/data/2.5/weather?q=codrington&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 263 | Pimentel
# https://api.openweathermap.org/data/2.5/weather?q=pimentel&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 264 | Hambantota
# https://api.openweathermap.org/data/2.5/weather?q=hambantota&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 265 | Quatre Cocos
# https://api.openweathermap.org/data/2.5/weather?q=quatre cocos&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 266 | San Isidro
# https://api.openweathermap.org/data/2.5/weather?q=san isidro&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 267 | Silver City
# https://api.openweathermap.org/data/2.5/weather?q=silver city&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 268 | Bacolod
# https://api.openweathermap.org/data/2.5/weather?q=bacolod&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 269 | Maymyo
# https://api.openweathermap.org/data/2.5/weather?q=maymyo&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 270 | Gewane
# https://api.openweathermap.org/data/2.5/weather?q=gewane&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# Exception for city erikoussa
# 'name'
# City Record 271 | Kampong Cham
# https://api.openweathermap.org/data/2.5/weather?q=kampong cham&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 272 | Huai Yot
# https://api.openweathermap.org/data/2.5/weather?q=huai yot&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 273 | Tucuman
# https://api.openweathermap.org/data/2.5/weather?q=tucuman&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 274 | Port Blair
# https://api.openweathermap.org/data/2.5/weather?q=port blair&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 275 | Hay River
# https://api.openweathermap.org/data/2.5/weather?q=hay river&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 276 | Pakxan
# https://api.openweathermap.org/data/2.5/weather?q=pakxan&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 277 | Russkaya Polyana
# https://api.openweathermap.org/data/2.5/weather?q=russkaya polyana&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 278 | Omboue
# https://api.openweathermap.org/data/2.5/weather?q=omboue&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 279 | Pingliang
# https://api.openweathermap.org/data/2.5/weather?q=pingliang&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 280 | Koulikoro
# https://api.openweathermap.org/data/2.5/weather?q=koulikoro&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 281 | Andros Town
# https://api.openweathermap.org/data/2.5/weather?q=andros town&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 282 | Malartic
# https://api.openweathermap.org/data/2.5/weather?q=malartic&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 283 | Istanbul
# https://api.openweathermap.org/data/2.5/weather?q=istanbul&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 284 | Swiecie
# https://api.openweathermap.org/data/2.5/weather?q=swiecie&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# Exception for city geresk
# 'name'
# City Record 285 | Birjand
# https://api.openweathermap.org/data/2.5/weather?q=birjand&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 286 | Klaksvik
# https://api.openweathermap.org/data/2.5/weather?q=klaksvik&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 287 | Upernavik
# https://api.openweathermap.org/data/2.5/weather?q=upernavik&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# Exception for city saleaula
# 'name'
# City Record 288 | Bendigo
# https://api.openweathermap.org/data/2.5/weather?q=bendigo&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 289 | Tyup
# https://api.openweathermap.org/data/2.5/weather?q=tyup&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 290 | Balabac
# https://api.openweathermap.org/data/2.5/weather?q=balabac&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 291 | Sokna
# https://api.openweathermap.org/data/2.5/weather?q=sokna&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 292 | Labuhan
# https://api.openweathermap.org/data/2.5/weather?q=labuhan&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 293 | Ilo
# https://api.openweathermap.org/data/2.5/weather?q=ilo&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 294 | Naze
# https://api.openweathermap.org/data/2.5/weather?q=naze&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 295 | Berlevag
# https://api.openweathermap.org/data/2.5/weather?q=berlevag&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 296 | Paita
# https://api.openweathermap.org/data/2.5/weather?q=paita&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 297 | Mokhsogollokh
# https://api.openweathermap.org/data/2.5/weather?q=mokhsogollokh&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# Exception for city pemangkat
# 'name'
# City Record 298 | Umm Kaddadah
# https://api.openweathermap.org/data/2.5/weather?q=umm kaddadah&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 299 | Mangai
# https://api.openweathermap.org/data/2.5/weather?q=mangai&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 300 | Leningradskiy
# https://api.openweathermap.org/data/2.5/weather?q=leningradskiy&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 301 | Cayenne
# https://api.openweathermap.org/data/2.5/weather?q=cayenne&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 302 | Kamaishi
# https://api.openweathermap.org/data/2.5/weather?q=kamaishi&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 303 | Dali
# https://api.openweathermap.org/data/2.5/weather?q=dali&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 304 | Buchanan
# https://api.openweathermap.org/data/2.5/weather?q=buchanan&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 305 | Suluq
# https://api.openweathermap.org/data/2.5/weather?q=suluq&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 306 | Buluang
# https://api.openweathermap.org/data/2.5/weather?q=buluang&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 307 | Wakkanai
# https://api.openweathermap.org/data/2.5/weather?q=wakkanai&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 308 | Ranong
# https://api.openweathermap.org/data/2.5/weather?q=ranong&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 309 | Thompson
# https://api.openweathermap.org/data/2.5/weather?q=thompson&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 310 | Kaitangata
# https://api.openweathermap.org/data/2.5/weather?q=kaitangata&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 311 | Tautira
# https://api.openweathermap.org/data/2.5/weather?q=tautira&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 312 | Adrar
# https://api.openweathermap.org/data/2.5/weather?q=adrar&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 313 | Katobu
# https://api.openweathermap.org/data/2.5/weather?q=katobu&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 314 | Mecca
# https://api.openweathermap.org/data/2.5/weather?q=mecca&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 315 | Mmathubudukwane
# https://api.openweathermap.org/data/2.5/weather?q=mmathubudukwane&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 316 | Changji
# https://api.openweathermap.org/data/2.5/weather?q=changji&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 317 | Qaanaaq
# https://api.openweathermap.org/data/2.5/weather?q=qaanaaq&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 318 | Okotoks
# https://api.openweathermap.org/data/2.5/weather?q=okotoks&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 319 | Lexington
# https://api.openweathermap.org/data/2.5/weather?q=lexington&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 320 | Durango
# https://api.openweathermap.org/data/2.5/weather?q=durango&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 321 | Manutuke
# https://api.openweathermap.org/data/2.5/weather?q=manutuke&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 322 | La Rioja
# https://api.openweathermap.org/data/2.5/weather?q=la rioja&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 323 | Tura
# https://api.openweathermap.org/data/2.5/weather?q=tura&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 324 | Sao Filipe
# https://api.openweathermap.org/data/2.5/weather?q=sao filipe&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 325 | Manavalakurichi
# https://api.openweathermap.org/data/2.5/weather?q=manavalakurichi&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# Exception for city kashi
# 'name'
# City Record 326 | Khargone
# https://api.openweathermap.org/data/2.5/weather?q=khargone&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 327 | Westport
# https://api.openweathermap.org/data/2.5/weather?q=westport&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 328 | Astoria
# https://api.openweathermap.org/data/2.5/weather?q=astoria&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 329 | Shingu
# https://api.openweathermap.org/data/2.5/weather?q=shingu&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 330 | Casimiro Castillo
# https://api.openweathermap.org/data/2.5/weather?q=casimiro castillo&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 331 | Shakhtinsk
# https://api.openweathermap.org/data/2.5/weather?q=shakhtinsk&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 332 | Kruisfontein
# https://api.openweathermap.org/data/2.5/weather?q=kruisfontein&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 333 | Agadez
# https://api.openweathermap.org/data/2.5/weather?q=agadez&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 334 | San Andres
# https://api.openweathermap.org/data/2.5/weather?q=san andres&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 335 | Egvekinot
# https://api.openweathermap.org/data/2.5/weather?q=egvekinot&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 336 | Taoudenni
# https://api.openweathermap.org/data/2.5/weather?q=taoudenni&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 337 | Andahuaylas
# https://api.openweathermap.org/data/2.5/weather?q=andahuaylas&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 338 | Moose Factory
# https://api.openweathermap.org/data/2.5/weather?q=moose factory&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 339 | Kupang
# https://api.openweathermap.org/data/2.5/weather?q=kupang&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 340 | Mocuba
# https://api.openweathermap.org/data/2.5/weather?q=mocuba&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# Exception for city labutta
# 'name'
# City Record 341 | Powassan
# https://api.openweathermap.org/data/2.5/weather?q=powassan&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 342 | Najran
# https://api.openweathermap.org/data/2.5/weather?q=najran&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 343 | Clyde River
# https://api.openweathermap.org/data/2.5/weather?q=clyde river&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# Exception for city wulanhaote
# 'name'
# Exception for city gorno-chuyskiy
# 'name'
# City Record 344 | Lahaina
# https://api.openweathermap.org/data/2.5/weather?q=lahaina&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 345 | Fortuna
# https://api.openweathermap.org/data/2.5/weather?q=fortuna&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 346 | Mackay
# https://api.openweathermap.org/data/2.5/weather?q=mackay&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# Exception for city turkistan
# 'name'
# City Record 347 | Makakilo City
# https://api.openweathermap.org/data/2.5/weather?q=makakilo city&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 348 | Vao
# https://api.openweathermap.org/data/2.5/weather?q=vao&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 349 | Guerrero Negro
# https://api.openweathermap.org/data/2.5/weather?q=guerrero negro&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 350 | Afsin
# https://api.openweathermap.org/data/2.5/weather?q=afsin&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 351 | Ust-Kuyga
# https://api.openweathermap.org/data/2.5/weather?q=ust-kuyga&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 352 | Bambari
# https://api.openweathermap.org/data/2.5/weather?q=bambari&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 353 | Kachiry
# https://api.openweathermap.org/data/2.5/weather?q=kachiry&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 354 | Tabou
# https://api.openweathermap.org/data/2.5/weather?q=tabou&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 355 | Bayshore Gardens
# https://api.openweathermap.org/data/2.5/weather?q=bayshore gardens&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# Exception for city villa oliva
# 'name'
# City Record 356 | Abu Zabad
# https://api.openweathermap.org/data/2.5/weather?q=abu zabad&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 357 | Pringsewu
# https://api.openweathermap.org/data/2.5/weather?q=pringsewu&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# Exception for city barawe
# 'name'
# City Record 358 | Bridlington
# https://api.openweathermap.org/data/2.5/weather?q=bridlington&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 359 | Dingle
# https://api.openweathermap.org/data/2.5/weather?q=dingle&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 360 | Vardo
# https://api.openweathermap.org/data/2.5/weather?q=vardo&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 361 | Pacifica
# https://api.openweathermap.org/data/2.5/weather?q=pacifica&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 362 | Waipawa
# https://api.openweathermap.org/data/2.5/weather?q=waipawa&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 363 | Port Macquarie
# https://api.openweathermap.org/data/2.5/weather?q=port macquarie&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 364 | Valparaiso
# https://api.openweathermap.org/data/2.5/weather?q=valparaiso&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 365 | Laguna
# https://api.openweathermap.org/data/2.5/weather?q=laguna&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 366 | Bealanana
# https://api.openweathermap.org/data/2.5/weather?q=bealanana&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 367 | Manggar
# https://api.openweathermap.org/data/2.5/weather?q=manggar&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 368 | Verdun
# https://api.openweathermap.org/data/2.5/weather?q=verdun&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 369 | Atambua
# https://api.openweathermap.org/data/2.5/weather?q=atambua&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# ...
# City Record 443 | Vestmanna
# https://api.openweathermap.org/data/2.5/weather?q=vestmanna&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 444 | Mahanoro
# https://api.openweathermap.org/data/2.5/weather?q=mahanoro&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 445 | Hovd
# https://api.openweathermap.org/data/2.5/weather?q=hovd&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 446 | Campos Belos
# https://api.openweathermap.org/data/2.5/weather?q=campos belos&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 447 | Khromtau
# https://api.openweathermap.org/data/2.5/weather?q=khromtau&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 448 | Bethanien
# https://api.openweathermap.org/data/2.5/weather?q=bethanien&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 449 | Ludinghausen
# https://api.openweathermap.org/data/2.5/weather?q=ludinghausen&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 450 | Erzincan
# https://api.openweathermap.org/data/2.5/weather?q=erzincan&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 451 | Saint-Pierre
# https://api.openweathermap.org/data/2.5/weather?q=saint-pierre&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 452 | Deputatskiy
# https://api.openweathermap.org/data/2.5/weather?q=deputatskiy&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 453 | Menzelinsk
# https://api.openweathermap.org/data/2.5/weather?q=menzelinsk&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 454 | Porto Franco
# https://api.openweathermap.org/data/2.5/weather?q=porto franco&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 455 | Toora-Khem
# https://api.openweathermap.org/data/2.5/weather?q=toora-khem&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 456 | Ballina
# https://api.openweathermap.org/data/2.5/weather?q=ballina&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 457 | La Ronge
# https://api.openweathermap.org/data/2.5/weather?q=la ronge&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 458 | Katsuura
# https://api.openweathermap.org/data/2.5/weather?q=katsuura&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 459 | Borisoglebsk
# https://api.openweathermap.org/data/2.5/weather?q=borisoglebsk&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 460 | Okha
# https://api.openweathermap.org/data/2.5/weather?q=okha&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 461 | The Valley
# https://api.openweathermap.org/data/2.5/weather?q=the valley&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 462 | Brigantine
# https://api.openweathermap.org/data/2.5/weather?q=brigantine&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 463 | Bati
# https://api.openweathermap.org/data/2.5/weather?q=bati&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 464 | Mutsu
# https://api.openweathermap.org/data/2.5/weather?q=mutsu&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 465 | Rezzato
# https://api.openweathermap.org/data/2.5/weather?q=rezzato&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 466 | Lufilufi
# https://api.openweathermap.org/data/2.5/weather?q=lufilufi&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 467 | Arman
# https://api.openweathermap.org/data/2.5/weather?q=arman&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 468 | Arrifes
# https://api.openweathermap.org/data/2.5/weather?q=arrifes&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 469 | Alice Springs
# https://api.openweathermap.org/data/2.5/weather?q=alice springs&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 470 | Ponazyrevo
# https://api.openweathermap.org/data/2.5/weather?q=ponazyrevo&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 471 | Kharp
# https://api.openweathermap.org/data/2.5/weather?q=kharp&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 472 | Khon Buri
# https://api.openweathermap.org/data/2.5/weather?q=khon buri&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 473 | Yatou
# https://api.openweathermap.org/data/2.5/weather?q=yatou&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 474 | Deniliquin
# https://api.openweathermap.org/data/2.5/weather?q=deniliquin&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# Exception for city linguere
# 'name'
# City Record 475 | Mandali
# https://api.openweathermap.org/data/2.5/weather?q=mandali&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 476 | Merauke
# https://api.openweathermap.org/data/2.5/weather?q=merauke&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 477 | Martorell
# https://api.openweathermap.org/data/2.5/weather?q=martorell&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 478 | Steinbach
# https://api.openweathermap.org/data/2.5/weather?q=steinbach&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 479 | Omsukchan
# https://api.openweathermap.org/data/2.5/weather?q=omsukchan&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 480 | Mul
# https://api.openweathermap.org/data/2.5/weather?q=mul&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 481 | Le Moule
# https://api.openweathermap.org/data/2.5/weather?q=le moule&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 482 | Cortland
# https://api.openweathermap.org/data/2.5/weather?q=cortland&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 483 | Itoman
# https://api.openweathermap.org/data/2.5/weather?q=itoman&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 484 | Charters Towers
# https://api.openweathermap.org/data/2.5/weather?q=charters towers&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 485 | Yerbogachen
# https://api.openweathermap.org/data/2.5/weather?q=yerbogachen&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# Exception for city westpunt
# 'name'
# City Record 486 | Xam Nua
# https://api.openweathermap.org/data/2.5/weather?q=xam nua&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 487 | Panaba
# https://api.openweathermap.org/data/2.5/weather?q=panaba&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 488 | Sidi Ali
# https://api.openweathermap.org/data/2.5/weather?q=sidi ali&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 489 | Den Helder
# https://api.openweathermap.org/data/2.5/weather?q=den helder&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 490 | Seidu
# https://api.openweathermap.org/data/2.5/weather?q=seidu&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 491 | Carauari
# https://api.openweathermap.org/data/2.5/weather?q=carauari&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 492 | Yeppoon
# https://api.openweathermap.org/data/2.5/weather?q=yeppoon&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 493 | Itaituba
# https://api.openweathermap.org/data/2.5/weather?q=itaituba&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 494 | Kargasok
# https://api.openweathermap.org/data/2.5/weather?q=kargasok&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 495 | Winslow
# https://api.openweathermap.org/data/2.5/weather?q=winslow&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# Exception for city marcona
# 'name'
# City Record 496 | Nieuw Amsterdam
# https://api.openweathermap.org/data/2.5/weather?q=nieuw amsterdam&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# Exception for city bur gabo
# 'name'
# City Record 497 | Lethbridge
# https://api.openweathermap.org/data/2.5/weather?q=lethbridge&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# Exception for city khormuj
# 'name'
# City Record 498 | Cassilandia
# https://api.openweathermap.org/data/2.5/weather?q=cassilandia&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 499 | Esso
# https://api.openweathermap.org/data/2.5/weather?q=esso&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 500 | Beian
# https://api.openweathermap.org/data/2.5/weather?q=beian&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 501 | Rabaul
# https://api.openweathermap.org/data/2.5/weather?q=rabaul&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 502 | Mahuva
# https://api.openweathermap.org/data/2.5/weather?q=mahuva&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 503 | Scarborough
# https://api.openweathermap.org/data/2.5/weather?q=scarborough&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 504 | Hastings
# https://api.openweathermap.org/data/2.5/weather?q=hastings&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 505 | Sangre Grande
# https://api.openweathermap.org/data/2.5/weather?q=sangre grande&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 506 | Batagay-Alyta
# https://api.openweathermap.org/data/2.5/weather?q=batagay-alyta&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 507 | Sovetskiy
# https://api.openweathermap.org/data/2.5/weather?q=sovetskiy&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 508 | Guatire
# https://api.openweathermap.org/data/2.5/weather?q=guatire&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 509 | Hays
# https://api.openweathermap.org/data/2.5/weather?q=hays&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 510 | Dudinka
# https://api.openweathermap.org/data/2.5/weather?q=dudinka&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 511 | Baykit
# https://api.openweathermap.org/data/2.5/weather?q=baykit&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 512 | Cabedelo
# https://api.openweathermap.org/data/2.5/weather?q=cabedelo&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 513 | Cap Malheureux
# https://api.openweathermap.org/data/2.5/weather?q=cap malheureux&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 514 | Pangnirtung
# https://api.openweathermap.org/data/2.5/weather?q=pangnirtung&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 515 | Onalaska
# https://api.openweathermap.org/data/2.5/weather?q=onalaska&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 516 | Dekar
# https://api.openweathermap.org/data/2.5/weather?q=dekar&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 517 | Chateauroux
# https://api.openweathermap.org/data/2.5/weather?q=chateauroux&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 518 | Mabama
# https://api.openweathermap.org/data/2.5/weather?q=mabama&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 519 | Narsaq
# https://api.openweathermap.org/data/2.5/weather?q=narsaq&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 520 | Southampton
# https://api.openweathermap.org/data/2.5/weather?q=southampton&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 521 | Mandalgovi
# https://api.openweathermap.org/data/2.5/weather?q=mandalgovi&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 522 | Kungurtug
# https://api.openweathermap.org/data/2.5/weather?q=kungurtug&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 523 | Santa Rosa
# https://api.openweathermap.org/data/2.5/weather?q=santa rosa&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 524 | Igrim
# https://api.openweathermap.org/data/2.5/weather?q=igrim&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 525 | Maceio
# https://api.openweathermap.org/data/2.5/weather?q=maceio&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 526 | Gumdag
# https://api.openweathermap.org/data/2.5/weather?q=gumdag&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 527 | Gat
# https://api.openweathermap.org/data/2.5/weather?q=gat&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 528 | Wangkui
# https://api.openweathermap.org/data/2.5/weather?q=wangkui&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# Exception for city lalomanu
# 'name'
# City Record 529 | Yulara
# https://api.openweathermap.org/data/2.5/weather?q=yulara&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 530 | Xichang
# https://api.openweathermap.org/data/2.5/weather?q=xichang&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 531 | Kampot
# https://api.openweathermap.org/data/2.5/weather?q=kampot&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 532 | Townsville
# https://api.openweathermap.org/data/2.5/weather?q=townsville&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 533 | Tutoia
# https://api.openweathermap.org/data/2.5/weather?q=tutoia&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 534 | Tabuk
# https://api.openweathermap.org/data/2.5/weather?q=tabuk&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 535 | Guarapari
# https://api.openweathermap.org/data/2.5/weather?q=guarapari&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 536 | Nalut
# https://api.openweathermap.org/data/2.5/weather?q=nalut&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 537 | Limbang
# https://api.openweathermap.org/data/2.5/weather?q=limbang&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# Exception for city zhanatas
# 'name'
# City Record 538 | San Martin
# https://api.openweathermap.org/data/2.5/weather?q=san martin&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 539 | Ermelo
# https://api.openweathermap.org/data/2.5/weather?q=ermelo&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 540 | Nanortalik
# https://api.openweathermap.org/data/2.5/weather?q=nanortalik&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 541 | Ambon
# https://api.openweathermap.org/data/2.5/weather?q=ambon&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 542 | Dauphin
# https://api.openweathermap.org/data/2.5/weather?q=dauphin&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 543 | Oliveira dos Brejinhos
# https://api.openweathermap.org/data/2.5/weather?q=oliveira dos brejinhos&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 544 | La Asuncion
# https://api.openweathermap.org/data/2.5/weather?q=la asuncion&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 545 | Road Town
# https://api.openweathermap.org/data/2.5/weather?q=road town&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 546 | Kununurra
# https://api.openweathermap.org/data/2.5/weather?q=kununurra&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# Exception for city haibowan
# 'name'
# City Record 547 | Santa Cecilia
# https://api.openweathermap.org/data/2.5/weather?q=santa cecilia&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 548 | Lamlash
# https://api.openweathermap.org/data/2.5/weather?q=lamlash&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 549 | Half Moon Bay
# https://api.openweathermap.org/data/2.5/weather?q=half moon bay&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 550 | Samana
# https://api.openweathermap.org/data/2.5/weather?q=samana&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 551 | Vila
# https://api.openweathermap.org/data/2.5/weather?q=vila&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 552 | Lamar
# https://api.openweathermap.org/data/2.5/weather?q=lamar&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 553 | Choya
# https://api.openweathermap.org/data/2.5/weather?q=choya&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 554 | Sao Francisco
# https://api.openweathermap.org/data/2.5/weather?q=sao francisco&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 555 | Haapiti
# https://api.openweathermap.org/data/2.5/weather?q=haapiti&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# Exception for city longlac
# 'name'
# City Record 556 | San-Pedro
# https://api.openweathermap.org/data/2.5/weather?q=san-pedro&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 557 | Timbiqui
# https://api.openweathermap.org/data/2.5/weather?q=timbiqui&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 558 | Hervey Bay
# https://api.openweathermap.org/data/2.5/weather?q=hervey bay&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 559 | Kaeo
# https://api.openweathermap.org/data/2.5/weather?q=kaeo&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 560 | Sinnamary
# https://api.openweathermap.org/data/2.5/weather?q=sinnamary&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 561 | Agropoli
# https://api.openweathermap.org/data/2.5/weather?q=agropoli&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 562 | Shetpe
# https://api.openweathermap.org/data/2.5/weather?q=shetpe&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 563 | Kieta
# https://api.openweathermap.org/data/2.5/weather?q=kieta&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 564 | Matipo
# https://api.openweathermap.org/data/2.5/weather?q=matipo&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 565 | Sistranda
# https://api.openweathermap.org/data/2.5/weather?q=sistranda&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# Exception for city julana
# 'name'
# City Record 566 | Bani
# https://api.openweathermap.org/data/2.5/weather?q=bani&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d
# City Record 567 | Rome
# https://api.openweathermap.org/data/2.5/weather?q=roma&APPID=ffe6134d89ef4aaa5fcdcc40a1d83b8d

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weatherpy_dictionary = {
    "City": city_name,
    "Cloudiness":cloudiness, 
    "Country":country,
    "Date":date, 
    "Humidity": humidity,
    "Lat":lat, 
    "Lng":lng, 
    "Max Temp": city_temperature,
    "Wind Speed":wind_speed
}

# Create df 
weather_data = pd.DataFrame(weatherpy_dictionary)

# Display count
weather_data.count()
# Out:
# City          567
# Cloudiness    567
# Country       567
# Date          567
# Humidity      567
# Lat           567
# Lng           567
# Max Temp      567
# Wind Speed    567
# dtype: int64

# %%
# Save data frame to CSV
weather_data.to_csv('weather_data.csv')

# Display data frame head 
weather_data.head(20)
# Out:
#            City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0     Busselton          36      AU  1563148769        66 -33.64  115.35
# 1        Albany           1      US  1563148769        73  42.65  -73.75
# 2       Ushuaia          20      AR  1563148569        94 -54.81  -68.31
# 3         Vaini          91      IN  1563148772        90  15.34   74.49
# 4     Geraldton          90      CA  1563148784        88  49.72  -86.95
# 5     Sadiqabad           0      PK  1563148786        62  28.31   70.13
# 6     Tuatapere          93      NZ  1563148787        90 -46.13  167.69
# 7        Faanui          37      PF  1563148789        80 -16.48 -151.75
# 8       Rikitea          28      PF  1563148791        86 -23.12 -134.97
# 9   Provideniya          20      RU  1563148792        66  64.42 -173.23
# 10      Dunedin          13      NZ  1563148794        46 -45.87  170.50
# 11       Bassar          64      TG  1563148795        84   9.26    0.78
# 12        Along         100      IN  1563148797        99  28.17   94.80
# 13    Inhambane           0      MZ  1563148248        93 -23.87   35.38
# 14    Penapolis          30      BR  1563148567        48 -21.42  -50.08
# 15  East London           0      ZA  1563148801        84 -33.02   27.91
# 16        Bluff          91      AU  1563148803        39 -23.58  149.07
# 17       Mehamn         100      NO  1563148264        87  71.03   27.85
# 18    Saskylakh           0      RU  1563148808        54  71.97  114.09
# 19   Naryan-Mar         100      RU  1563148809        90  67.67   53.09
#
#     Max Temp  Wind Speed
# 0     280.69        9.01
# 1     296.44        4.10
# 2     276.15        2.10
# 3     297.81        0.56
# 4     293.15        4.10
# 5     302.01        5.64
# 6     278.71        1.79
# 7     299.21        4.41
# 8     297.11        6.31
# 9     286.15        6.00
# 10    284.26        4.92
# 11    297.01        2.06
# 12    288.71        1.75
# 13    288.61        1.48
# 14    295.21        0.97
# 15    284.61        1.56
# 16    285.61        0.85
# 17    279.11        3.66
# 18    282.71        5.51
# 19    281.21        2.11

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(weather_data["Lat"], weather_data["Max Temp"], marker="o", s=10)
plt.title("City Latitude vs. City Temperature")
plt.ylabel("City Temperature (F)")
plt.xlabel("City Latitude")
plt.grid(True)

plt.savefig("Temperature_v_Latitude.png")
plt.show()

# %%
weather_data["Lat"]
# Out:
# 0     -33.64
# 1      42.65
# 2     -54.81
# 3      15.34
# 4      49.72
# 5      28.31
# 6     -46.13
# 7     -16.48
# 8     -23.12
# 9      64.42
# 10    -45.87
# 11      9.26
# 12     28.17
# 13    -23.87
# 14    -21.42
# 15    -33.02
# 16    -23.58
# 17     71.03
# 18     71.97
# 19     67.67
# 20    -53.16
# 21     -0.90
# 22     73.51
# 23     37.17
# 24    -22.95
# 25     13.22
# 26     45.36
# 27     68.54
# 28     52.85
# 29     59.77
#        ...
# 537    37.08
# 538    52.30
# 539    60.14
# 540    47.55
# 541    51.15
# 542   -12.32
# 543   -26.05
# 544    18.42
# 545   -15.77
# 546     9.85
# 547    55.53
# 548    37.46
# 549     0.12
# 550    45.18
# 551    38.09
# 552    52.01
# 553   -25.65
# 554   -17.57
# 555     4.75
# 556     2.77
# 557   -25.30
# 558   -35.10
# 559     5.38
# 560    40.35
# 561    44.14
# 562    -6.22
# 563   -20.28
# 564    63.73
# 565    16.02
# 566    41.89
# Name: Lat, Length: 567, dtype: float64

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(weather_data["Lat"], weather_data["Humidity"], marker="o", s=10)
plt.title("City Latitude vs. City Humidity")
plt.ylabel("City Humidity (%)")
plt.xlabel("City Latitude")
plt.grid(True)

plt.savefig("Humidity_v_Latitude.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_data["Lat"], weather_data["Cloudiness"], marker="o", s=10)
plt.title("City Latitude vs. Cloudiness")
plt.ylabel("City Cloudiness (%)")
plt.xlabel("City Latitude")
plt.grid(True)

plt.savefig("Cloudiness_v_Latitude.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_data["Lat"], weather_data["Wind Speed"], marker="o", s=10)
plt.title("City Latitude vs. Wind Speed")
plt.ylabel("City Wind Speed (mph)")
plt.xlabel("City Latitude")
plt.grid(True)

plt.savefig("WindSpeed_v_Latitude.png")
plt.show()
